# %%
#1. 은행만들기

# %% [markdown]
# 1. Account 클래스 : 은행에서 계좌를 개설하면 은행이름, 예금주, 계좌번로, 잔액이 설정
# 2. Account 위의 속성이 생성자로 구현
# 3. 초기값은 'SC은행'
# 4. 계좌번호 3자리-2자리 -6자리 형태로 랜덤하게 생성

# %%
import random
class Account :
    accout_count = 0 
    def __init__(self, name, balance): 
        self.name = name
        self.balance = balance
        self.bank ='SC은행'
        num1 = random.randint(0,999)
        num2 = random.randint(0,99)
        num3 = random.randint(0,999999)

        num1 = str(num1).zfill(3)  # 1 -> '1' -> '001' 자리수 오류 방지 위함
        num2 = str(num2).zfill(2)
        num3 = str(num3).zfill(6)      
        self.account_number = str(num1) + "-" + str(num2) + "-" + str(num3) 
        Account.account_count += 1
    @classmethod 
    def get_account_number (cls):
        print(cls.account_count)

# %%
kim = Account('홍길동', 100)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-f707e4287a23> in <module>
# ----> 1 kim = Account('홍길동', 100)
#
# <ipython-input-10-8c23d3af8b6a> in __init__(self, name, balance)
#      14         num3 = str(num3).zfill(6)
#      15         self.account_number = str(num1) + "-" + str(num2) + "-" + str(num3)
# ---> 16         Account.account_count += 1
#      17     @classmethod
#      18     def get_account_number (cls):
#
# AttributeError: type object 'Account' has no attribute 'account_count'

# %%
lee = Account('이길동', 200)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-f5bc64a0a75a> in <module>
# ----> 1 lee = Account('이길동', 200)
#
# <ipython-input-1-8c23d3af8b6a> in __init__(self, name, balance)
#      14         num3 = str(num3).zfill(6)
#      15         self.account_number = str(num1) + "-" + str(num2) + "-" + str(num3)
# ---> 16         Account.account_count += 1
#      17     @classmethod
#      18     def get_account_number (cls):
#
# AttributeError: type object 'Account' has no attribute 'account_count'

# %%
 print(kim.bank)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-fb48cefa1763> in <module>
# ----> 1 print(kim.bank)
#
# NameError: name 'kim' is not defined

# %%
 print(kim.balance)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-eb1dcc15f7c0> in <module>
# ----> 1 print(kim.balance)
#
# NameError: name 'kim' is not defined

# %%
 print(kim.account_number)
# Out:
# 029-79-312475

# %%
a = Account('홍길동1', 100)

# %%
 print(a.account_number)
# Out:
# 218-59-437088

# %%
b = Account('홍길동2', 100)
print(b.account_number)
# Out:
# 924-35-860626

# %%
print(self.name)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-6fda824df725> in <module>
# ----> 1 print(self.name)
#
# NameError: name 'self' is not defined

# %%
print(kim.account_number)
# Out:
# 029-79-312475

# %%
def  wrap(func):
    def docorated():
        print('반갑습니다.') #시작부분 삽입
        func()
        print('잘가요')
    return decorated

# %%
@wrap
def hello():
    print('hi~', "홍길동")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-2db42ce40b99> in <module>
#       1 @wrap
# ----> 2 def hello():
#       3     print('hi~', "홍길동")
#       4
#
# <ipython-input-31-3706c9c5445f> in wrap(func)
#       4         func()
#       5         print('잘가요')
# ----> 6     return decorated
#       7
#
# NameError: name 'decorated' is not defined

# %%
import random
class Account :
    accout_count = 0 
    def __init__(self, name, balance): 
        self.name = name
        self.balance = balance
        self.bank ='SC은행'
        num1 = random.randint(0,999)
        num2 = random.randint(0,99)
        num3 = random.randint(0,999999)

        num1 = str(num1).zfill(3)  # 1 -> '1' -> '001' 자리수 오류 방지 위함
        num2 = str(num2).zfill(2)
        num3 = str(num3).zfill(6)      
        self.account_number = (num1) + "-" +  (num2) + "-" +  (num3) 
        Account.account_count += 1
    @classmethod 
    def get_account_num(cls):
        print(cls.account_count)

    # deposit 입금메소드 입금은 최소 1원이상 
    def deposit(self, amount):
        if amount >= 1:
            self.balance += amount
    def withdraw(self, amount):
        if self.balance > amount:
            self.balance -= amount
    def display_info(self):
        print("은행이름:", self.bank)
        print("예금주:", self.name)  
        print("계좌번호:", self.account_number)
        print("잔고:", self.balance)

# %%
p = Accont("파이썬", 10000)
p.display_info()

# %%
kim = Account('김길동', 100)
# kim.balance
#kim.deposit(100)

# %%
kim.balance

# %%
kim.withdraw(90)

# %%
#Account 인스턴스에 저장된 정보를 출력하는  display_info()메소드 추가
#잔고는 세자리 마다 , 쉽표를 출력하시요 
#은행명 : SC은행
#예금주 : 파이썬 
#계좌번로 : 111-11-111111
#잔고 : 10,000원
